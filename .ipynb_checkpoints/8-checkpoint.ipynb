# %%
import pandas as pd

# %%
df=pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df[['Name','Sex','Ticket','Cabin','Embarked']]
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# ...

# %%
df.dtypes=='object'
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name            True
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
df[df.dtypes[df.dtypes=='int64'].index]
# Out:
#      PassengerId  Survived  Pclass  SibSp  Parch
# 0              1         0       3      1      0
# 1              2         1       1      1      0
# 2              3         1       3      0      0
# 3              4         1       1      1      0
# 4              5         0       3      0      0
# ..           ...       ...     ...    ...    ...
# 886          887         0       2      0      0
# 887          888         1       1      0      0
# 888          889         0       3      1      2
# 889          890         1       1      0      0
# 890          891         0       3      0      0
#
# [891 rows x 5 columns]

# %%
df.tail(15)
# Out:
#      PassengerId  Survived  Pclass  \
# 876          877         0       3
# 877          878         0       3
# 878          879         0       3
# 879          880         1       1
# 880          881         1       2
# 881          882         0       3
# 882          883         0       3
# 883          884         0       2
# 884          885         0       3
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                               Name     Sex   Age  SibSp  \
# 876                  Gustafsson, Mr. Alfred Ossian    male  20.0      0
# 877                           Petroff, Mr. Nedelio    male  19.0      0
# 878                             Laleff, Mr. Kristo    male   NaN      0
# 879  Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# ...

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df[['Ticket']]
# Out:
#                Ticket
# 0           A/5 21171
# 1            PC 17599
# 2    STON/O2. 3101282
# 3              113803
# 4              373450
# ..                ...
# 886            211536
# 887            112053
# 888        W./C. 6607
# 889            111369
# 890            370376
#
# [891 rows x 1 columns]

# %%
df[['Ticket']][4:16]
# Out:
#        Ticket
# 4      373450
# 5      330877
# 6       17463
# 7      349909
# 8      347742
# 9      237736
# 10    PP 9549
# 11     113783
# 12  A/5. 2151
# 13     347082
# 14     350406
# 15     248706

# %%
df[['Ticket']][4:16:2]
# Out:
#        Ticket
# 4      373450
# 6       17463
# 8      347742
# 10    PP 9549
# 12  A/5. 2151
# 14     350406

# %%
df[['Ticket','Cabin']]
# Out:
#                Ticket Cabin
# 0           A/5 21171   NaN
# 1            PC 17599   C85
# 2    STON/O2. 3101282   NaN
# 3              113803  C123
# 4              373450   NaN
# ..                ...   ...
# 886            211536   NaN
# 887            112053   B42
# 888        W./C. 6607   NaN
# 889            111369  C148
# 890            370376   NaN
#
# [891 rows x 2 columns]

# %%
df[['Ticket','Cabin']][4:17:3]
# Out:
#      Ticket Cabin
# 4    373450   NaN
# 7    349909   NaN
# 10  PP 9549    G6
# 13   347082   NaN
# 16   382652   NaN

# %%
df[['Ticket','Cabin','Name']][4:17:3]
# Out:
#      Ticket Cabin                             Name
# 4    373450   NaN         Allen, Mr. William Henry
# 7    349909   NaN   Palsson, Master. Gosta Leonard
# 10  PP 9549    G6  Sandstrom, Miss. Marguerite Rut
# 13   347082   NaN      Andersson, Mr. Anders Johan
# 16   382652   NaN             Rice, Master. Eugene

# %%
df['swati']=2.5
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.insert(loc=4,column='age',value=4)
df
# Out:
#      PassengerId  Survived  Pclass  Food  age  \
# 0              1         0       3     0    4
# 1              2         1       1     0    4
# 2              3         1       3     0    4
# 3              4         1       1     0    4
# 4              5         0       3     0    4
# ..           ...       ...     ...   ...  ...
# 886          887         0       2     0    4
# 887          888         1       1     0    4
# 888          889         0       3     0    4
# 889          890         1       1     0    4
# 890          891         0       3     0    4
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %% [markdown]
# # Pandas library part 2

# %%
a=df['Name'][0:10]
a
# Out:
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# 5                                     Moran, Mr. James
# 6                              McCarthy, Mr. Timothy J
# 7                       Palsson, Master. Gosta Leonard
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                  Nasser, Mrs. Nicholas (Adele Achem)
# Name: Name, dtype: object

# %%
type(a)
# Out:
# pandas.core.series.Series

# %%
l=['swati','a2','a3','a4','a5','a6','a7','a8','a9','a10']
pd.Series(a,index=l)
# Out:
# swati    NaN
# a2       NaN
# a3       NaN
# a4       NaN
# a5       NaN
# a6       NaN
# a7       NaN
# a8       NaN
# a9       NaN
# a10      NaN
# Name: Name, dtype: object

# %%
pd.Series(list(a),index=l)
# Out:
# swati                              Braund, Mr. Owen Harris
# a2       Cumings, Mrs. John Bradley (Florence Briggs Th...
# a3                                  Heikkinen, Miss. Laina
# a4            Futrelle, Mrs. Jacques Heath (Lily May Peel)
# a5                                Allen, Mr. William Henry
# a6                                        Moran, Mr. James
# a7                                 McCarthy, Mr. Timothy J
# a8                          Palsson, Master. Gosta Leonard
# a9       Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# a10                    Nasser, Mrs. Nicholas (Adele Achem)
# dtype: object

# %%
m1=pd.Series([10,20,30,40,50],index=[1,2,3,4,5])
m1
# Out:
# 1    10
# 2    20
# 3    30
# 4    40
# 5    50
# dtype: int64

# %%
m2=pd.Series([100,200,300,400,500],index=[1,2,3,4,5])
m2
# Out:
# 1    100
# 2    200
# 3    300
# 4    400
# 5    500
# dtype: int64

# %%
m3=pd.concat([m1,m2])
m3
# Out:
# 1     10
# 2     20
# 3     30
# 4     40
# 5     50
# 1    100
# 2    200
# 3    300
# 4    400
# 5    500
# dtype: int64

# %%
m3[1]
# Out:
# 1     10
# 1    100
# dtype: int64

# %%
m1*m2
# Out:
# 1     1000
# 2     4000
# 3     9000
# 4    16000
# 5    25000
# dtype: int64

# %%
m1+m2
# Out:
# 1    110
# 2    220
# 3    330
# 4    440
# 5    550
# dtype: int64

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  Food  age  \
# 0            1         0       3     0    4
# 1            2         1       1     0    4
# 2            3         1       3     0    4
# 3            4         1       1     0    4
# 4            5         0       3     0    4
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  swati
# 0      0         A/5 21171   7.2500   NaN        S    2.5
# 1      0          PC 17599  71.2833   C85        C    2.5
# 2      0  STON/O2. 3101282   7.9250   NaN        S    2.5
# ...

# %%
df.drop("PassengerId",axis=1,inplace=True)

# %%
df.head()
# Out:
#    Pclass  Food  age                                               Name  \
# 0       3     0    4                            Braund, Mr. Owen Harris
# 1       1     0    4  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2       3     0    4                             Heikkinen, Miss. Laina
# 3       1     0    4       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4       3     0    4                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  swati
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S    2.5
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C    2.5
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S    2.5
# 3  female  35.0      1      0            113803  53.1000  C123        S    2.5
# 4    male  35.0      0      0            373450   8.0500   NaN        S    2.5

# %%
df.drop("Survived",axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 df.drop("Survived",axis=1,inplace=True)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
#    5263         level=level,
#    5264         inplace=inplace,
#    5265         errors=errors,
#    5266     )
#
# ...

# %%
df.head()
# Out:
#    Pclass  Food  age                                               Name  \
# 0       3     0    4                            Braund, Mr. Owen Harris
# 1       1     0    4  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2       3     0    4                             Heikkinen, Miss. Laina
# 3       1     0    4       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4       3     0    4                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  swati
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S    2.5
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C    2.5
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S    2.5
# 3  female  35.0      1      0            113803  53.1000  C123        S    2.5
# 4    male  35.0      0      0            373450   8.0500   NaN        S    2.5

# %%
df.set_index('Name')
# Out:
#                                                     Pclass  Food  age     Sex  \
# Name
# Braund, Mr. Owen Harris                                  3     0    4    male
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1     0    4  female
# Heikkinen, Miss. Laina                                   3     0    4  female
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1     0    4  female
# Allen, Mr. William Henry                                 3     0    4    male
# ...                                                    ...   ...  ...     ...
# Montvila, Rev. Juozas                                    2     0    4    male
# Graham, Miss. Margaret Edith                             1     0    4  female
# Johnston, Miss. Catherine Helen "Carrie"                 3     0    4  female
# Behr, Mr. Karl Howell                                    1     0    4    male
# Dooley, Mr. Patrick                                      3     0    4    male
#
# ...

# %%
df.head()
# Out:
#    Pclass  Food  age                                               Name  \
# 0       3     0    4                            Braund, Mr. Owen Harris
# 1       1     0    4  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2       3     0    4                             Heikkinen, Miss. Laina
# 3       1     0    4       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4       3     0    4                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  swati
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S    2.5
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C    2.5
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S    2.5
# 3  female  35.0      1      0            113803  53.1000  C123        S    2.5
# 4    male  35.0      0      0            373450   8.0500   NaN        S    2.5

# %%
df.set_index('Name',inplace=True)

# %%
df.head()
# Out:
#                                                     Pclass  Food  age     Sex  \
# Name
# Braund, Mr. Owen Harris                                  3     0    4    male
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1     0    4  female
# Heikkinen, Miss. Laina                                   3     0    4  female
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1     0    4  female
# Allen, Mr. William Henry                                 3     0    4    male
#
#                                                      Age  SibSp  Parch  \
# Name
# Braund, Mr. Owen Harris                             22.0      1      0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  38.0      1      0
# Heikkinen, Miss. Laina                              26.0      0      0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)        35.0      1      0
# Allen, Mr. William Henry                            35.0      0      0
#
# ...

# %%
df.reset_index()
# Out:
#                                                   Name  Pclass  Food  age  \
# 0                              Braund, Mr. Owen Harris       3     0    4
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...       1     0    4
# 2                               Heikkinen, Miss. Laina       3     0    4
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)       1     0    4
# 4                             Allen, Mr. William Henry       3     0    4
# ..                                                 ...     ...   ...  ...
# 886                              Montvila, Rev. Juozas       2     0    4
# 887                       Graham, Miss. Margaret Edith       1     0    4
# 888           Johnston, Miss. Catherine Helen "Carrie"       3     0    4
# 889                              Behr, Mr. Karl Howell       1     0    4
# 890                                Dooley, Mr. Patrick       3     0    4
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# ...

# %%
df.head()
# Out:
#                                                     Pclass  Food  age     Sex  \
# Name
# Braund, Mr. Owen Harris                                  3     0    4    male
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1     0    4  female
# Heikkinen, Miss. Laina                                   3     0    4  female
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1     0    4  female
# Allen, Mr. William Henry                                 3     0    4    male
#
#                                                      Age  SibSp  Parch  \
# Name
# Braund, Mr. Owen Harris                             22.0      1      0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  38.0      1      0
# Heikkinen, Miss. Laina                              26.0      0      0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)        35.0      1      0
# Allen, Mr. William Henry                            35.0      0      0
#
# ...

# %% [markdown]
# # making dataframe from dictionary

# %%
d={"key1":[1,2,3,4,5],
  "key2":[2,3,4,5,6],
   "key3":[5,6,7,8,9]
  }
print(d)
# Out:
# {'key1': [1, 2, 3, 4, 5], 'key2': [2, 3, 4, 5, 6], 'key3': [5, 6, 7, 8, 9]}

# %%
pd.DataFrame(d)
# Out:
#    key1  key2  key3
# 0     1     2     5
# 1     2     3     6
# 2     3     4     7
# 3     4     5     8
# 4     5     6     9

# %%
import pandas as pd
df1=pd.read_csv("free-taxonomy.csv")
df1
# Out:
#                         name     id parent_name  parent_id  \
# 0                  Emergency   1101           0        0.0
# 1                       Food   1102           0        0.0
# 2                    Housing   1103           0        0.0
# 3                      Goods   1104           0        0.0
# 4                    Transit   1105           0        0.0
# ..                       ...    ...         ...        ...
# 322                In Danger  20089     Urgency    20087.0
# 323          Chronic Illness  20090      Health     1106.0
# 324                  Spouses  20091        Role    20072.0
# 325               Dependents  20092        Role    20072.0
# 326  Intellectual Disability  20093  Disability    20017.0
#
#                             vocabulary  \
# 0      Open Eligibility Human Services
# 1      Open Eligibility Human Services
# 2      Open Eligibility Human Services
# 3      Open Eligibility Human Services
# 4      Open Eligibility Human Services
# ...

# %%
df1.dropna(inplace=True)

# %%
df1
# Out:
# Empty DataFrame
# Columns: [name, id, parent_name, parent_id, vocabulary, x-description, x-notes, services]
# Index: []

# %%
import pandas as pd
df2=pd.read_csv("free-taxonomy.csv")
df2
# Out:
#                         name     id parent_name  parent_id  \
# 0                  Emergency   1101           0        0.0
# 1                       Food   1102           0        0.0
# 2                    Housing   1103           0        0.0
# 3                      Goods   1104           0        0.0
# 4                    Transit   1105           0        0.0
# ..                       ...    ...         ...        ...
# 322                In Danger  20089     Urgency    20087.0
# 323          Chronic Illness  20090      Health     1106.0
# 324                  Spouses  20091        Role    20072.0
# 325               Dependents  20092        Role    20072.0
# 326  Intellectual Disability  20093  Disability    20017.0
#
#                             vocabulary  \
# 0      Open Eligibility Human Services
# 1      Open Eligibility Human Services
# 2      Open Eligibility Human Services
# 3      Open Eligibility Human Services
# 4      Open Eligibility Human Services
# ...

# %%
df2.dropna(axis=1,inplace=True)
df2
# Out:
#                         name     id                         vocabulary
# 0                  Emergency   1101    Open Eligibility Human Services
# 1                       Food   1102    Open Eligibility Human Services
# 2                    Housing   1103    Open Eligibility Human Services
# 3                      Goods   1104    Open Eligibility Human Services
# 4                    Transit   1105    Open Eligibility Human Services
# ..                       ...    ...                                ...
# 322                In Danger  20089  Open Eligibility Human Situations
# 323          Chronic Illness  20090  Open Eligibility Human Situations
# 324                  Spouses  20091  Open Eligibility Human Situations
# 325               Dependents  20092  Open Eligibility Human Situations
# 326  Intellectual Disability  20093  Open Eligibility Human Situations
#
# [327 rows x 3 columns]

# %%
import pandas as pd
df3=pd.read_csv("free-taxonomy.csv")
df3
# Out:
#                         name     id parent_name  parent_id  \
# 0                  Emergency   1101           0        0.0
# 1                       Food   1102           0        0.0
# 2                    Housing   1103           0        0.0
# 3                      Goods   1104           0        0.0
# 4                    Transit   1105           0        0.0
# ..                       ...    ...         ...        ...
# 322                In Danger  20089     Urgency    20087.0
# 323          Chronic Illness  20090      Health     1106.0
# 324                  Spouses  20091        Role    20072.0
# 325               Dependents  20092        Role    20072.0
# 326  Intellectual Disability  20093  Disability    20017.0
#
#                             vocabulary  \
# 0      Open Eligibility Human Services
# 1      Open Eligibility Human Services
# 2      Open Eligibility Human Services
# 3      Open Eligibility Human Services
# 4      Open Eligibility Human Services
# ...

# %%
df3.fillna("yash",inplace=True)
df3
# Out:
#                         name     id parent_name parent_id  \
# 0                  Emergency   1101           0       0.0
# 1                       Food   1102           0       0.0
# 2                    Housing   1103           0       0.0
# 3                      Goods   1104           0       0.0
# 4                    Transit   1105           0       0.0
# ..                       ...    ...         ...       ...
# 322                In Danger  20089     Urgency   20087.0
# 323          Chronic Illness  20090      Health    1106.0
# 324                  Spouses  20091        Role   20072.0
# 325               Dependents  20092        Role   20072.0
# 326  Intellectual Disability  20093  Disability   20017.0
#
#                             vocabulary  \
# 0      Open Eligibility Human Services
# 1      Open Eligibility Human Services
# 2      Open Eligibility Human Services
# 3      Open Eligibility Human Services
# 4      Open Eligibility Human Services
# ...
