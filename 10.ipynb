# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
var1 = [1,2,3,4,5,6,7,8]
var2 = [8,7,6,5,4,3,2,1]

plt.plot(var1,var2)
plt.show()

# %%
sns.lineplot(x= var1 , y= var2)
plt.show()

# %%
var1 = [1,2,3,4,5,6,7,8]
var2 = [8,7,6,5,4,3,2,1]

import pandas as pd

df = pd.DataFrame({"var1":var1, "var2":var2})
sns.lineplot(x = 'var1', y='var2',data=df)

plt.show()

# %%
df
# Out:
#    var1  var2
# 0     1     8
# 1     2     7
# 2     3     6
# 3     4     5
# 4     5     4
# 5     6     3
# 6     7     2
# 7     8     1

# %%
import pandas as pd
df1=pd.read_csv("penguins.csv")
df1
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    MALE
# 1         3800.0  FEMALE
# ...

# %%
sns.lineplot(x="bill_length_mm",y="flipper_length_mm",data=df1)
plt.show()

# %%
sns.lineplot(x="bill_length_mm",y="flipper_length_mm",data=df1,hue="sex")
plt.show()

# %%
sns.lineplot(x="bill_length_mm",y="flipper_length_mm",data=df1,hue="sex",palette="rocket_r")
plt.show()

# %%
sns.lineplot(x="bill_length_mm",y="flipper_length_mm",data=df1,hue="sex",palette="rocket_r",style="sex",markers=["o",">"])
plt.show()

# %%
df1=pd.read_csv("penguins.csv").head(20)
df1
# Out:
#    species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0   Adelie  Torgersen            39.1           18.7              181.0
# 1   Adelie  Torgersen            39.5           17.4              186.0
# 2   Adelie  Torgersen            40.3           18.0              195.0
# 3   Adelie  Torgersen             NaN            NaN                NaN
# 4   Adelie  Torgersen            36.7           19.3              193.0
# 5   Adelie  Torgersen            39.3           20.6              190.0
# 6   Adelie  Torgersen            38.9           17.8              181.0
# 7   Adelie  Torgersen            39.2           19.6              195.0
# 8   Adelie  Torgersen            34.1           18.1              193.0
# 9   Adelie  Torgersen            42.0           20.2              190.0
# 10  Adelie  Torgersen            37.8           17.1              186.0
# 11  Adelie  Torgersen            37.8           17.3              180.0
# ...

# %%
sns.lineplot(x="bill_length_mm",y="flipper_length_mm",data=df1,hue="sex",palette="rocket_r",style="sex",markers=["o",">"])
plt.show()

# %%
sns.lineplot(x="bill_length_mm",y="flipper_length_mm",data=df1,hue="sex",palette="rocket_r",style="sex",markers=["o",">"])
plt.grid()
plt.show()

# %%
sns.lineplot(x="bill_length_mm",y="flipper_length_mm",data=df1,hue="sex",palette="rocket_r",style="sex",
             markers=["o",">"])
plt.grid()
plt.title("this is the line fraph")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

df1=pd.read_csv("penguins.csv")
df1
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    MALE
# 1         3800.0  FEMALE
# ...

# %%
df1["island"]
# Out:
# 0      Torgersen
# 1      Torgersen
# 2      Torgersen
# 3      Torgersen
# 4      Torgersen
#          ...
# 339       Biscoe
# 340       Biscoe
# 341       Biscoe
# 342       Biscoe
# 343       Biscoe
# Name: island, Length: 344, dtype: object

# %%
sns.barplot(x=df1.island,y=df1.bill_length_mm)
plt.show()

# %%
sns.barplot(x=df1.island,y=df1.bill_length_mm,data=df1)
plt.show()

# %%
sns.barplot(x=df1.island,y=df1.bill_length_mm,data=df1,hue="sex")
plt.show()

# %% [markdown]
# # Order

# %%
order1=["Dream","Torgersen","Biscoe"]
sns.barplot(x=df1.island,y=df1.bill_length_mm,data=df1,hue="sex",order=order1)
plt.show()

# %%
order1=["Dream","Torgersen","Biscoe"]
sns.barplot(x=df1.island,y=df1.bill_length_mm,data=df1,hue="sex",order=order1,hue_order = ['FEMALE','MALE'])
plt.show()

# %%
order1=["Dream","Torgersen","Biscoe"]
sns.barplot(x=df1.island,y=df1.bill_length_mm,data=df1,color="green")
plt.show()

# %%
order1=["Dream","Torgersen","Biscoe"]
sns.barplot(x=df1.island,y=df1.bill_length_mm,data=df1,hue="sex",palette="Accent")
plt.show()

# %%
order1=["Dream","Torgersen","Biscoe"]
sns.barplot(x=df1.island,y=df1.bill_length_mm,data=df1,hue="sex",palette="gist_earth")
plt.show()

# %%
order1=["Dream","Torgersen","Biscoe"]
sns.barplot(x=df1.island,y=df1.bill_length_mm,data=df1,hue="sex",palette="gist_earth",saturation=0.5)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
df1
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    MALE
# 1         3800.0  FEMALE
# ...

# %%
sns.displot(df1["flipper_length_mm"])
plt.show()
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(df1["flipper_length_mm"],bins=[170,180,190,200,210,220,230,240])
plt.show()
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(df1["flipper_length_mm"],bins=[170,180,190,200,210,220,230,240],color='red')
plt.show()
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(df1["flipper_length_mm"],bins=[170,180,190,200,210,220,230,240],color='red',kde=True)
plt.show()
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
